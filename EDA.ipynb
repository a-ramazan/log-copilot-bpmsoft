# %%
import pandas as pd

# %%
clusters_df = pd.read_csv('out/clusters.csv')
clusters_df.head()
# Out:
#                                  cluster_id   hits  \
# 0  bcf7ccfa3769e3c11c7d4e5d73836d32162d8e6d  38585
# 1  fa1582cf0c1899a9a1d4c38fddf955d450c62f01  34178
# 2  586e5fa236eb592c2f837dbb469c327414578dfe  12212
# 3  a41cf6f75ef368f7a4bf4b800bd6eb4d5c58d4ea   7804
# 4  aeca61d6a830206393bf9671a31580cb9527e275   6030
#
#                    first_seen                   last_seen  \
# 0  2025-10-20 14:59:08.071000  2026-03-16 13:16:00.012000
# 1  2025-10-21 10:59:00.041000  2026-03-16 13:16:00.012000
# 2  2025-10-20 14:59:08.092000  2026-03-16 13:15:00.044000
# 3  2025-10-20 14:59:08.147000  2026-03-16 13:15:00.044000
# 4  2025-11-01 10:20:03.938000  2026-03-16 13:15:03.942000
#
#                                         source_files  \
# 0  2026-02-19/BusinessProcess.log (673); 2025-11-...
# 1  2026-02-19/BusinessProcess.log (657); 2026-02-...
# 2  2025-10-21/BusinessProcess.log (503); 2025-10-...
# 3  2026-02-19/BusinessProcess.log (136); 2025-11-...
# ...

# %%
events_df = pd.read_csv('out/events.csv')
events_df.head(10)
# Out:
#                                event_id           source_file  \
# 0  d9a0bf36-b0c2-4067-bc84-fcb90d281b99   2025-10-20/Auth.log
# 1  f1d1c64d-7f42-4378-977a-8f7a0153b54d  2025-10-20/Build.log
# 2  65bd122e-9f9a-4f83-83d5-c3f5967240b0  2025-10-20/Build.log
# 3  9c1f4420-9553-4d0e-a937-e4087066b789  2025-10-20/Build.log
# 4  a2cb5381-1b61-4d9f-ad62-917870bbe94c  2025-10-20/Build.log
# 5  848a9d37-d84c-4612-9804-b1489e704b61  2025-10-20/Build.log
# 6  75c5db86-aac0-4810-85ed-00a9416699db  2025-10-20/Build.log
# 7  2275fcf7-3f76-434e-9c2b-b95765797c4e  2025-10-20/Build.log
# 8  84d35d62-30f4-42e4-9822-31a79c170879  2025-10-20/Build.log
# 9  5b20fbdb-b830-4f04-a9d7-75537f3e8a5c  2025-10-20/Build.log
#
#                     timestamp level  \
# 0                         NaN   NaN
# 1  2025-10-20 15:00:09.313000  INFO
# 2  2025-10-20 15:00:20.692000  INFO
# 3  2025-10-20 15:00:20.729000  INFO
# 4  2025-10-20 15:00:38.833000  INFO
# 5  2025-10-20 15:00:38.843000  INFO
# ...

# %%
events_df.isna().sum()
# Out:
# event_id                    0
# source_file                 0
# timestamp                 131
# level                  559774
# message                     0
# stacktrace            2146894
# normalized_message          0
# signature_hash              0
# request_id            2263237
# trace_id              2263237
# exception_type        2148218
# stack_frames          2148241
# http_status           1703594
# is_incident                 0
# dtype: int64

# %%
from collections import Counter
Counter('rgrsdfdfd')
# Out:
# Counter({'d': 3, 'r': 2, 'f': 2, 'g': 1, 's': 1})

# %%
events_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2263237 entries, 0 to 2263236
# Data columns (total 14 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   event_id            object
#  1   source_file         object
#  2   timestamp           object
#  3   level               object
#  4   message             object
#  5   stacktrace          object
#  6   normalized_message  object
#  7   signature_hash      object
#  8   request_id          float64
#  9   trace_id            float64
#  10  exception_type      object
#  11  stack_frames        object
#  12  http_status         float64
#  13  is_incident         bool
# dtypes: bool(1), float64(3), object(10)
# memory usage: 226.6+ MB

# %%
clusters_df = pd.read_csv('out_single_aspnet/clusters.csv')
clusters_df.head()
# Out:
#                                  cluster_id  hits                  first_seen  \
# 0  70671b53e51b77e2d57508e52d9242c15f2cc58c     5  2026-03-11 12:07:09.415000
# 1  99a419925ad7c24a906fff94ee264bddb926ce4e     2  2026-03-11 08:21:15.050000
# 2  b0a00e30646ed9a0c86d9ab612dd58e24f963f87     2  2026-03-11 08:21:15.037000
# 3  2269aa1f91d7e17650c15bdd3316c423a0696319     1  2026-03-11 12:07:14.830000
# 4  d519d774372b497ad934721a29f4b0a38db076a9     1  2026-03-11 08:20:49.723000
#
#                     last_seen   parser_profiles        source_files  \
# 0  2026-03-11 12:07:14.672000  log4net_like (5)  aspnetcore.log (5)
# 1  2026-03-11 08:21:50.750000  log4net_like (2)  aspnetcore.log (2)
# 2  2026-03-11 08:21:50.735000  log4net_like (2)  aspnetcore.log (2)
# 3  2026-03-11 12:07:14.830000  log4net_like (1)  aspnetcore.log (1)
# 4  2026-03-11 08:20:49.723000  log4net_like (1)  aspnetcore.log (1)
#
#                                      sample_messages  \
# ...

# %%
clusters_df = pd.read_csv('out_single_aspnet/events.csv')
clusters_df.head()
# Out:
#                                event_id     source_file parser_profile  \
# 0  4b22adc4-0b44-4f5d-b4ab-f0e41e743f18  aspnetcore.log   log4net_like
# 1  3c16268c-ddb6-4d53-9d4c-a918cb99a140  aspnetcore.log   log4net_like
# 2  2a7a7d30-e02c-4685-8beb-e582b4d7aeec  aspnetcore.log   log4net_like
# 3  78df1eb5-2efa-4289-8fa3-9a1e34d60e21  aspnetcore.log   log4net_like
# 4  8f0b5fe8-e355-4a5c-8fe7-af98525fe38a  aspnetcore.log   log4net_like
#
#                     timestamp  level  \
# 0  2026-03-11 08:20:48.390000   WARN
# 1  2026-03-11 08:20:49.617000  FATAL
# 2  2026-03-11 08:20:49.723000  ERROR
# 3  2026-03-11 08:21:14.469000   WARN
# 4  2026-03-11 08:21:15.037000  FATAL
#
#                                            component  \
# 0  Microsoft.AspNetCore.DataProtection.Repositori...
# 1     Microsoft.AspNetCore.Hosting.Diagnostics Start
# 2  Microsoft.Extensions.Hosting.Internal.Host Sta...
# 3  Microsoft.AspNetCore.DataProtection.Repositori...
# ...
